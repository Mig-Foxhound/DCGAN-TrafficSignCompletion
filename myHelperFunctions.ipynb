# %%
import cv2
import glob
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact, interactive, fixed
from moviepy.editor import VideoFileClip
from IPython.display import HTML
import matplotlib.pyplot as plt
import csv

# %%
images = glob.glob("FullIJCNN2013/*.ppm")
i = 0
for fname in images:
    img = cv2.imread(fname)
    cv2.imwrite('TestImage/'+ str(i) +'.png',img)
    if i %100 == 0:
        print (i)
    i += 1

# %%
# The German Traffic Sign Recognition Benchmark
#
# sample code for reading the traffic sign images and the
# corresponding labels
#
# example:
#            
# trainImages, trainLabels = readTrafficSigns('GTSRB/Training')
# print len(trainLabels), len(trainImages)
# plt.imshow(trainImages[42])
# plt.show()
#
# have fun, Christian



# function for reading the images
# arguments: path to the traffic sign data, for example './GTSRB/Training'
# returns: list of images, list of corresponding labels 
def readTrafficSigns(rootpath):
    '''Reads traffic sign data for German Traffic Sign Recognition Benchmark.

    Arguments: path to the traffic sign data, for example './GTSRB/Training'
    Returns:   list of images, list of corresponding labels'''
    images = [] # images
    labels = [] # corresponding labels
    # loop over all 42 classes
    for c in range(0,43):
        prefix = rootpath + '/' + format(c, '05d') + '/' # subdirectory for class
        gtFile = open(prefix + 'GT-'+ format(c, '05d') + '.csv') # annotations file
        gtReader = csv.reader(gtFile, delimiter=';') # csv parser for annotations file
        next(gtReader) # skip header
        # loop over all images in current annotations file
        for row in gtReader:
            images.append(plt.imread(prefix + row[0])) # the 1th column is the filename
            labels.append(row[7]) # the 8th column is the label
        gtFile.close()
    return images, labels

# %%
trainImages, trainLabels = readTrafficSigns('GTSRB/Final_Test/Images')
print (len(trainLabels), len(trainImages))
plt.imshow(trainImages[42])
plt.show()
# Out:
# 39209 39209

# %%
i = 0
for c in range(0,43):
    folder = str(c).zfill(5)
    images = glob.glob("GTSRB2/Final_Training/Images/"+ folder +"/*.ppm")
    print (len(images))   
    for fname in images:
        img = cv2.imread(fname)
        cv2.imwrite('AllTrafficImage/'+ str(i) +'.png',img)
        if i %1000 == 0:
            print (i)
        i += 1
# Out:
# 210
# 0
# 2220
# 1000
# 2000
# 2250
# 3000
# 4000
# 1410
# 5000
# 6000
# 1980
# 7000
# 8000
# 1860
# 9000
# 420
# 10000
# 1440
# 11000
# 1410
# 12000
# 13000
# 1470
# 14000
# 2010
# 15000
# 16000
# 1320
# 17000
# 2100
# 18000
# 19000
# 20000
# 2160
# 21000
# 22000
# 780
# 23000
# 630
# 420
# 24000
# 1110
# 25000
# 1200
# 26000
# 210
# 360
# 330
# 27000
# 390
# 510
# 28000
# 270
# 1500
# 29000
# 600
# 30000
# 240
# 540
# 31000
# 270
# 450
# 32000
# 780
# 240
# 33000
# 689
# 420
# 34000
# 1200
# 35000
# 390
# 210
# 2070
# 36000
# 37000
# 38000
# 300
# 360
# 240
# 240
# 39000

# %%
labels = []
gtFile = open('GTSRB/GT-final_test.csv')
gtReader = csv.reader(gtFile, delimiter=';') # csv parser for annotations file
next(gtReader) # skip header
# loop over all images in current annotations file
for row in gtReader:
    labels.append(row[7])
print (labels)
# Out:
# ['16', '1', '38', '33', '11', '38', '18', '12', '25', '35', '12', '7', '23', '7', '4', '9', '21', '20', '27', '38', '4', '33', '9', '3', '1', '11', '13', '10', '9', '11', '5', '17', '34', '23', '2', '17', '3', '12', '16', '8', '7', '30', '18', '12', '24', '25', '3', '10', '18', '8', '25', '13', '15', '9', '13', '35', '5', '26', '9', '16', '38', '10', '4', '9', '15', '9', '26', '2', '5', '28', '11', '25', '30', '34', '5', '12', '1', '10', '25', '25', '21', '33', '25', '7', '10', '35', '3', '7', '22', '13', '3', '1', '2', '14', '12', '32', '3', '38', '9', '33', '1', '10', '5', '11', '33', '4', '35', '25', '33', '4', '1', '14', '16', '10', '30', '3', '27', '29', '1', '17', '13', '7', '1', '8', '2', '10', '10', '30', '1', '6', '36', '3', '14', '13', '11', '10', '18', '40', '2', '38', '41', '4', '6', '18', '17', '25', '2', '41', '11', '21', '7', '24', '11', '25', '17', '3', '6', '9', '7', '4', '13', '16', '4', '25', '18', '9', '13', '14', '29', '17', '13', '38', '26', '25', '33', '1', '3'
# ...

# %%
#14 is stop sign
#get all none- stop signs
inputPath = './GTSRB/Final_Test/Images'
outputPath = './Not_Stop_Sign'
i = 0
images = glob.glob(inputPath + "/*.ppm")

for i in range(800):
    img = cv2.imread(inputPath + "/"+ str(i).zfill(5) +".ppm")
    resizedImg = cv2.resize(img, (32,32))
    if labels[i] != '14':
        cv2.imwrite(outputPath + '/' + str(i).zfill(5) +'.png',img)
    
print ('...')
# Out:
# ...
